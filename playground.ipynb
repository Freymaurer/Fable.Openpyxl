# %%
import openpyxl

# %%
path = "C:\\Users\\Kevin\\Desktop\\BookTest.xlsx"

# To open the workbook 
# workbook object is created
wb_obj = openpyxl.load_workbook(path)

# Get workbook active sheet object
# from the active attribute
sheet_obj = wb_obj.active

# Cell objects also have a row, column, 
# and coordinate attributes that provide
# location information for the cell.
 
# Note: The first row or 
# column integer is 1, not 0.
 
# Cell object is created by using 
# sheet object's cell() method.
cell_obj = sheet_obj.cell(row = 1, column = 1)
 
# Print value of cell object 
# using the value attribute
print(cell_obj.value)
# Out:
# A1

# %%
from openpyxl import Workbook
from openpyxl.worksheet.table import Table, TableStyleInfo

tab = Table(displayName="Table1", ref="A1:E5")

tab.name = "Test"

tab.displayName
# Out:
# 'Table1'

# %%
import openpyxl
import io

def read_excel_to_bytes(file_path):
    # Load the Excel workbook
    workbook = openpyxl.load_workbook(file_path)

    # Create a BytesIO object to store the Excel data
    excel_bytes = io.BytesIO()

    # Save the workbook to the BytesIO object
    workbook.save(excel_bytes)

    # Get the bytes from the BytesIO object
    excel_bytes_data = excel_bytes.getvalue()

    return excel_bytes_data

def write_bytes(bytes, path):
    # Write the bytes data to the output file path using shutil
    with open(path, 'wb') as output_file:
        output_file.write(bytes)

# Replace 'your_file.xlsx' with the path to your Excel file
file_path = 'MinimalTest.xlsx'
excel_bytes_data = read_excel_to_bytes(file_path)
write_bytes(excel_bytes_data, "ByteTest.xlsx")
print(excel_bytes_data)
# Out:
# b'PK\x03\x04\x14\x00\x00\x00\x08\x00\xc7U\x84WFZ\xc1\x0c\x82\x00\x00\x00\xb1\x00\x00\x00\x10\x00\x00\x00docProps/app.xmlM\x8eM\x0b\xc20\x10D\xffJ\xe9\xddnU\xf0 1 \xd4\xa3\xe0\xc9{H76\x90dCv\x85\xfc|S\xc1\x8f\xdb<\xde0\x8c\xba\x15\xcaX\xc4#w5\x86\xc4\xa7~\x11\xc9G\x00\xb6\x0bF\xc3C\xd3\xa9\x19G%\x1aiX\x1e@\xcey\x8b\x13\xd9g\xc4$\xb0\x1b\xc7\x03`\x15L3\xce\x9b\xfc\x1d\xec\xb5:\xe7\x1c\xbc5\xe2)\xe9\xab\xb7\x85\x98\x9ct\x97j1(\xf8\x97k\xf3\x8e\x85\xd7\xbc\x1f\xb6o\xf9a\x05\xbf\x93\xfa\x05PK\x03\x04\x14\x00\x00\x00\x08\x00\xc7U\x84W3\xc7\x91M\t\x01\x00\x00\xf8\x01\x00\x00\x11\x00\x00\x00docProps/core.xml\x85\x91\xcdN\xc30\x10\x84_%\xca\xdd\xb1\x9d?Q+\xcd\x01P/P\t\x89H n\x96\xbdm-b\xc7\xb2\ri\xdf\x9e4\xa4i\xab"q\xdc\x99\xd9ow\xb5\x95\xb0Lt\x0e^\\g\xc1\x05\x05>\xda\xeb\xd6x&\xec2\xde\x85`\x19\xc6^\xec@s\x9f\x0c\t3\x98\x9b\xcei\x1e\x86\xd2m\xb1\xe5\xe2\x93o\x01\xa7\x84\x94XC\xe0\x92\x07\x8e\x8f@dgb<!\xa5\x98\x91\xf6\xcb\xb5#@\n\x0c-h0\xc1c\x9aP|\xce\x06p\xda\xff\xd90:sr\xef\xd5\x9c\xea\xfb>
# ...
